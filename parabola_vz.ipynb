# %%
import matplotlib.pyplot as plt 

y = []
for i in range(-20, 21):
    y.append(i*i)

plt.title('Parabola', size=20)
plt.xlabel('x')
plt.ylabel('y')
plt.text(16,200, 'y=x^2', size=20, style='italic')
plt.grid(alpha=0.2, ls=':')
plt.plot(y, lw=3, ls='--', color='#03befc')
plt.show()
